# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Three-Dimensional points and lines

# %%
plt.figure(figsize=(5, 5))
ax = plt.axes(projection='3d')
z = np.linspace(0, 15, 1000)
x = np.sin(z)
y = np.cos(z)

ax.plot3D(x, y, z, 'red')

# data for the three-dimensional scattered points

z = 15 * np.random.random(100)
x = np.sin(z) + 0.1 * np.random.randn(100)
y = np.cos(z) + 0.1 * np.random.randn(100)
ax.scatter3D(x, y, z, c=z, cmap='Greens')
plt.show()

# %% [markdown]
# # Three-Dimensional countor plots

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

# %%
x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)
x, y = np.meshgrid(x, y)
z = f(x, y)

fig = plt.figure(figsize=(5, 5))
ax = plt.axes(projection='3d')
ax.contour3D(x, y, z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.show()

# %% [markdown]
# # Chessboard

# %%
def chess(x, y):
    return (1 - x / 2 + x ** 5 + y ** 6) * np.exp(-(x ** 2 + y ** 2))

# %%
plt.figure(figsize=(5, 5))

dx, dy = 0.015, 0.05
x = np.arange(-4.0, 4.0, dx)
y = np.arange(-4.0, 4.0, dy)

X, Y = np.meshgrid(x, y)
extent = np.min(x), np.max(x), np.min(y), np.max(y)
z1 = np.add.outer(range(8), range(8)) % 2
plt.imshow(z1, cmap='binary_r', interpolation='nearest', extent=extent, alpha=1)

z2 = chess(X, Y)
plt.imshow(z2, alpha=0, interpolation='bilinear', extent=extent)
plt.title('Make your move')
plt.show()

# %% [markdown]
# # Multiple Violin Plots

# %%
import seaborn as sns

# %%
data = sns.load_dataset('tips')

# %%
plt.figure(figsize=(6, 4))
sns.violinplot(x='day', y='total_bill', data=data)
plt.show()

# %% [markdown]
# # Fidget Spinner game

# %%
from turtle import *

# %%
state = {'turn': 0}

# %%
def spinner():
    clear()
    angle = state['turn']/10
    right(angle)
    forward(100)
    dot(120, 'red')
    back(100)
    
    right(120)
    forward(100)
    dot(120, 'green')
    back(100)
    right(120)
    forward(100)
    
    dot(120, 'blue')
    back(100)
    right(120)
    update()

# %%
def animate():
    if state['turn'] > 0:
        state['turn'] -= 1
    spinner()
    ontimer(animate, 20)

# %%
def flick():
    state['turn'] += 10

# %%
setup(420, 420, 370, 0)
hideturtle()
tracer(False)
width(20)
onkey(flick, 'space')
listen()
animate()
done()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\grego\Anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\grego\Anaconda3\lib\tkinter\__init__.py", line 814, in callit
#     func(*args)
#   File "C:\Users\grego\AppData\Local\Temp\ipykernel_6160\2967628628.py", line 5, in animate
#     ontimer(animate, 20)
#   File "<string>", line 5, in ontimer
# turtle.Terminator
